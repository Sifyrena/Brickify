# %% [markdown]
# # com.FWPhys.Brickify
#
# Build your photos in bricks.
#
# Of course, this should only serve as a first-pass automated system in your pipeline. Properly arranging the dots to accentuate features you want to is an inherently human (or ML) task.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import Brickify
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageCms
import PIL

# Proper programmers will want to murder me

# %%
### Biggest available single board is 48*48. You can supply your own. Be careful about aspect ratios.

BoardX = 48
BoardY = 48

BoardColor = "Grey"

# %%
Photo = Image.open("Base1.jpg")

# %%
Result = Brickify.ProjectToDCS(Photo, (BoardX, BoardY), 2, BoardColor)
# Out:
# <PIL.Image.Image image mode=RGB size=96x96 at 0x7FA578FBE4F0>
# (96, 96)
# (48, 48)
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA579003DF0>

# %%
Result[0].resize((BoardX*10,BoardY*10),resample = 0)
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FA578FBE850>

# %%
print("Shopping list:")

Result[1]
# Out:
# Shopping list:
# {'Black': 130,
#  'White': 17,
#  'Grey': 102,
#  'Bright Blue': 100,
#  'Dark Azur': 0,
#  'Yellowish Green': 219,
#  'Bright Green': 0,
#  'Bright Yellow': 890,
#  'Bright Orange': 624,
#  'Nougat': 119,
#  'Bright Red': 0,
#  'Reddish Brown': 24,
#  'Bright Purple': 0,
#  'Med Lavender': 79}

# %%
## Appendix. This is hard coded in the Python File but you're welcome to add to this list.

Brickify.ShowColors()
